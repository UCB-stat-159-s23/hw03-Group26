# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
import xarray as xr

from pathlib import Path

# Small style adjustments for more readable plots
plt.style.use("seaborn-whitegrid")
plt.rcParams["figure.figsize"] = (8, 6)
plt.rcParams["font.size"] = 14
# Out:
# /tmp/ipykernel_644/254379158.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %%
#Read in the C02 csv file and display it.

DATA_DIR = Path.home()/Path('shared/climate-data')

co2_file = DATA_DIR / "monthly_in_situ_co2_mlo_cleaned.csv"
co2data = pd.read_csv(co2_file, na_values=-99.99).dropna()
co2data
# Out:
#      year  month  date_index  fraction_date     c02  data_adjusted_season  \
# 2    1958      3       21259      1958.2027  315.70                314.43
# 3    1958      4       21290      1958.2877  317.45                315.16
# 4    1958      5       21320      1958.3699  317.51                314.71
# 6    1958      7       21381      1958.5370  315.86                315.19
# 7    1958      8       21412      1958.6219  314.93                316.19
# ..    ...    ...         ...            ...     ...                   ...
# 756  2021      1       44211      2021.0411  415.17                415.11
# 757  2021      2       44242      2021.1260  416.47                415.70
# 758  2021      3       44270      2021.2027  417.14                415.59
# 759  2021      4       44301      2021.2877  418.24                415.44
# 760  2021      5       44331      2021.3699  418.92                415.50
#
#      data_fit  data_adjusted_seasonally_fit  data_filled  \
# ...

# %% [markdown]
# The "hue" argument in the sns.lineplot() is used to group variables together and helps depict the relationship between the x and y variables. In this case, we want to group the x and y axes (months and C02 levels, respectively) together and group them via years.

# %%
#Create plot that shows "monthly cycle for all three years in the dataset." Question 1.

sns.lineplot(data=co2data, x="month", y="c02", hue="year")
# Out:
# <AxesSubplot: xlabel='month', ylabel='c02'>
